# %% [markdown]
# **Get all the text from the DAIC-WOZ server**

# %%
for i in range(436,493):
  s = "https://dcapswoz.ict.usc.edu/wwwdaicwoz/" + str(i) + "_P.zip"
  # !wget {s}
# Out:
# --2023-01-24 03:50:23--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/436_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 363433770 (347M) [application/zip]
# Saving to: ‘436_P.zip’
#
# 436_P.zip           100%[===================>] 346.60M  20.3MB/s    in 16s
#
# 2023-01-24 03:50:40 (21.4 MB/s) - ‘436_P.zip’ saved [363433770/363433770]
#
# --2023-01-24 03:50:40--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/437_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 430660635 (411M) [application/zip]
# Saving to: ‘437_P.zip’
#
# 437_P.zip           100%[===================>] 410.71M  9.35MB/s    in 26s
#
# 2023-01-24 03:51:06 (16.0 MB/s) - ‘437_P.zip’ saved [430660635/430660635]
#
# --2023-01-24 03:51:06--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/438_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 750265218 (716M) [application/zip]
# Saving to: ‘438_P.zip’
#
# 438_P.zip           100%[===================>] 715.51M  13.6MB/s    in 46s
#
# 2023-01-24 03:51:52 (15.6 MB/s) - ‘438_P.zip’ saved [750265218/750265218]
#
# --2023-01-24 03:51:53--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/439_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 655002825 (625M) [application/zip]
# Saving to: ‘439_P.zip’
#
# 439_P.zip           100%[===================>] 624.66M  7.58MB/s    in 63s
#
# 2023-01-24 03:52:56 (9.98 MB/s) - ‘439_P.zip’ saved [655002825/655002825]
#
# --2023-01-24 03:52:56--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/440_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 723597534 (690M) [application/zip]
# Saving to: ‘440_P.zip’
#
# 440_P.zip           100%[===================>] 690.08M  14.9MB/s    in 51s
#
# 2023-01-24 03:53:47 (13.5 MB/s) - ‘440_P.zip’ saved [723597534/723597534]
#
# --2023-01-24 03:53:47--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/441_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 477321639 (455M) [application/zip]
# Saving to: ‘441_P.zip’
#
# 441_P.zip           100%[===================>] 455.21M  37.6MB/s    in 12s
#
# 2023-01-24 03:54:00 (38.2 MB/s) - ‘441_P.zip’ saved [477321639/477321639]
#
# --2023-01-24 03:54:00--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/442_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 496710077 (474M) [application/zip]
# Saving to: ‘442_P.zip’
#
# 442_P.zip           100%[===================>] 473.70M  6.71MB/s    in 49s
#
# 2023-01-24 03:54:49 (9.72 MB/s) - ‘442_P.zip’ saved [496710077/496710077]
#
# --2023-01-24 03:54:49--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/443_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 361306660 (345M) [application/zip]
# Saving to: ‘443_P.zip’
#
# 443_P.zip           100%[===================>] 344.57M  39.1MB/s    in 9.1s
#
# 2023-01-24 03:54:58 (37.7 MB/s) - ‘443_P.zip’ saved [361306660/361306660]
#
# --2023-01-24 03:54:59--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/444_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 681757552 (650M) [application/zip]
# Saving to: ‘444_P.zip’
#
# 444_P.zip           100%[===================>] 650.17M  9.23MB/s    in 36s
#
# 2023-01-24 03:55:35 (18.2 MB/s) - ‘444_P.zip’ saved [681757552/681757552]
#
# --2023-01-24 03:55:35--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/445_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 362238228 (345M) [application/zip]
# Saving to: ‘445_P.zip’
#
# 445_P.zip           100%[===================>] 345.46M  13.0MB/s    in 28s
#
# 2023-01-24 03:56:03 (12.5 MB/s) - ‘445_P.zip’ saved [362238228/362238228]
#
# --2023-01-24 03:56:03--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/446_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 519306760 (495M) [application/zip]
# Saving to: ‘446_P.zip’
#
# 446_P.zip           100%[===================>] 495.25M  11.5MB/s    in 36s
#
# 2023-01-24 03:56:39 (13.8 MB/s) - ‘446_P.zip’ saved [519306760/519306760]
#
# --2023-01-24 03:56:39--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/447_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 425496647 (406M) [application/zip]
# Saving to: ‘447_P.zip’
#
# 447_P.zip           100%[===================>] 405.79M  11.1MB/s    in 26s
#
# 2023-01-24 03:57:05 (15.4 MB/s) - ‘447_P.zip’ saved [425496647/425496647]
#
# --2023-01-24 03:57:06--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/448_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 648356257 (618M) [application/zip]
# Saving to: ‘448_P.zip’
#
# 448_P.zip           100%[===================>] 618.32M  44.6MB/s    in 15s
#
# 2023-01-24 03:57:21 (42.2 MB/s) - ‘448_P.zip’ saved [648356257/648356257]
#
# --2023-01-24 03:57:21--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/449_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 537409710 (513M) [application/zip]
# Saving to: ‘449_P.zip’
#
# 449_P.zip           100%[===================>] 512.51M  21.3MB/s    in 22s
#
# 2023-01-24 03:57:43 (23.1 MB/s) - ‘449_P.zip’ saved [537409710/537409710]
#
# --2023-01-24 03:57:43--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/450_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 661364831 (631M) [application/zip]
# Saving to: ‘450_P.zip’
#
# 450_P.zip           100%[===================>] 630.73M  6.72MB/s    in 59s
#
# 2023-01-24 03:58:42 (10.8 MB/s) - ‘450_P.zip’ saved [661364831/661364831]
#
# --2023-01-24 03:58:42--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/451_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 614260932 (586M) [application/zip]
# Saving to: ‘451_P.zip’
#
# 451_P.zip           100%[===================>] 585.80M  11.3MB/s    in 37s
#
# 2023-01-24 03:59:20 (15.6 MB/s) - ‘451_P.zip’ saved [614260932/614260932]
#
# --2023-01-24 03:59:20--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/452_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 459206512 (438M) [application/zip]
# Saving to: ‘452_P.zip’
#
# 452_P.zip           100%[===================>] 437.93M  15.2MB/s    in 28s
#
# 2023-01-24 03:59:48 (15.6 MB/s) - ‘452_P.zip’ saved [459206512/459206512]
#
# --2023-01-24 03:59:48--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/453_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 524487275 (500M) [application/zip]
# Saving to: ‘453_P.zip’
#
# 453_P.zip           100%[===================>] 500.19M  12.5MB/s    in 38s
#
# 2023-01-24 04:00:27 (13.0 MB/s) - ‘453_P.zip’ saved [524487275/524487275]
#
# --2023-01-24 04:00:27--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/454_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 416158632 (397M) [application/zip]
# Saving to: ‘454_P.zip’
#
# 454_P.zip           100%[===================>] 396.88M  20.5MB/s    in 32s
#
# 2023-01-24 04:01:00 (12.2 MB/s) - ‘454_P.zip’ saved [416158632/416158632]
#
# --2023-01-24 04:01:01--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/455_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 381030858 (363M) [application/zip]
# Saving to: ‘455_P.zip’
#
# 455_P.zip           100%[===================>] 363.38M  8.67MB/s    in 32s
#
# 2023-01-24 04:01:33 (11.4 MB/s) - ‘455_P.zip’ saved [381030858/381030858]
#
# --2023-01-24 04:01:33--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/456_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 442233880 (422M) [application/zip]
# Saving to: ‘456_P.zip’
#
# 456_P.zip           100%[===================>] 421.75M  9.76MB/s    in 36s
#
# 2023-01-24 04:02:10 (11.6 MB/s) - ‘456_P.zip’ saved [442233880/442233880]
#
# --2023-01-24 04:02:10--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/457_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 496803363 (474M) [application/zip]
# Saving to: ‘457_P.zip’
#
# 457_P.zip           100%[===================>] 473.79M  7.02MB/s    in 50s
#
# 2023-01-24 04:03:01 (9.38 MB/s) - ‘457_P.zip’ saved [496803363/496803363]
#
# --2023-01-24 04:03:01--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/458_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 500760324 (478M) [application/zip]
# Saving to: ‘458_P.zip’
#
# 458_P.zip           100%[===================>] 477.56M  12.9MB/s    in 34s
#
# 2023-01-24 04:03:35 (14.0 MB/s) - ‘458_P.zip’ saved [500760324/500760324]
#
# --2023-01-24 04:03:35--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/459_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 506197754 (483M) [application/zip]
# Saving to: ‘459_P.zip’
#
# 459_P.zip           100%[===================>] 482.75M  11.0MB/s    in 39s
#
# 2023-01-24 04:04:15 (12.4 MB/s) - ‘459_P.zip’ saved [506197754/506197754]
#
# --2023-01-24 04:04:15--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/460_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-01-24 04:04:18 ERROR 404: Not Found.
#
# --2023-01-24 04:04:18--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/461_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 514500468 (491M) [application/zip]
# Saving to: ‘461_P.zip’
#
# 461_P.zip           100%[===================>] 490.67M  11.6MB/s    in 59s
#
# 2023-01-24 04:05:17 (8.31 MB/s) - ‘461_P.zip’ saved [514500468/514500468]
#
# --2023-01-24 04:05:17--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/462_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 465991441 (444M) [application/zip]
# Saving to: ‘462_P.zip’
#
# 462_P.zip           100%[===================>] 444.40M  10.6MB/s    in 39s
#
# 2023-01-24 04:05:57 (11.3 MB/s) - ‘462_P.zip’ saved [465991441/465991441]
#
# --2023-01-24 04:05:57--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/463_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 435613013 (415M) [application/zip]
# Saving to: ‘463_P.zip’
#
# 463_P.zip           100%[===================>] 415.43M  17.9MB/s    in 38s
#
# 2023-01-24 04:06:35 (10.9 MB/s) - ‘463_P.zip’ saved [435613013/435613013]
#
# --2023-01-24 04:06:35--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/464_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 508623991 (485M) [application/zip]
# Saving to: ‘464_P.zip’
#
# 464_P.zip           100%[===================>] 485.06M  21.1MB/s    in 23s
#
# 2023-01-24 04:06:59 (20.9 MB/s) - ‘464_P.zip’ saved [508623991/508623991]
#
# --2023-01-24 04:06:59--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/465_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 608419517 (580M) [application/zip]
# Saving to: ‘465_P.zip’
#
# 465_P.zip           100%[===================>] 580.23M  8.55MB/s    in 53s
#
# 2023-01-24 04:07:52 (11.0 MB/s) - ‘465_P.zip’ saved [608419517/608419517]
#
# --2023-01-24 04:07:52--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/466_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 764370986 (729M) [application/zip]
# Saving to: ‘466_P.zip’
#
# 466_P.zip           100%[===================>] 728.96M  16.5MB/s    in 50s
#
# 2023-01-24 04:08:42 (14.7 MB/s) - ‘466_P.zip’ saved [764370986/764370986]
#
# --2023-01-24 04:08:42--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/467_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 456865998 (436M) [application/zip]
# Saving to: ‘467_P.zip’
#
# 467_P.zip           100%[===================>] 435.70M  7.24MB/s    in 42s
#
# 2023-01-24 04:09:24 (10.4 MB/s) - ‘467_P.zip’ saved [456865998/456865998]
#
# --2023-01-24 04:09:24--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/468_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 495083306 (472M) [application/zip]
# Saving to: ‘468_P.zip’
#
# 468_P.zip           100%[===================>] 472.15M  13.7MB/s    in 30s
#
# 2023-01-24 04:09:54 (16.0 MB/s) - ‘468_P.zip’ saved [495083306/495083306]
#
# --2023-01-24 04:09:54--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/469_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 562543982 (536M) [application/zip]
# Saving to: ‘469_P.zip’
#
# 469_P.zip           100%[===================>] 536.48M  12.9MB/s    in 44s
#
# 2023-01-24 04:10:39 (12.2 MB/s) - ‘469_P.zip’ saved [562543982/562543982]
#
# --2023-01-24 04:10:39--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/470_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 479018247 (457M) [application/zip]
# Saving to: ‘470_P.zip’
#
# 470_P.zip           100%[===================>] 456.83M  8.17MB/s    in 39s
#
# 2023-01-24 04:11:18 (11.8 MB/s) - ‘470_P.zip’ saved [479018247/479018247]
#
# --2023-01-24 04:11:18--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/471_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 531168307 (507M) [application/zip]
# Saving to: ‘471_P.zip’
#
# 471_P.zip           100%[===================>] 506.56M  12.7MB/s    in 44s
#
# 2023-01-24 04:12:02 (11.6 MB/s) - ‘471_P.zip’ saved [531168307/531168307]
#
# --2023-01-24 04:12:02--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/472_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 470067932 (448M) [application/zip]
# Saving to: ‘472_P.zip’
#
# 472_P.zip           100%[===================>] 448.29M  14.4MB/s    in 38s
#
# 2023-01-24 04:12:41 (11.8 MB/s) - ‘472_P.zip’ saved [470067932/470067932]
#
# --2023-01-24 04:12:41--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/473_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 268286880 (256M) [application/zip]
# Saving to: ‘473_P.zip’
#
# 473_P.zip           100%[===================>] 255.86M  8.08MB/s    in 21s
#
# 2023-01-24 04:13:02 (12.5 MB/s) - ‘473_P.zip’ saved [268286880/268286880]
#
# --2023-01-24 04:13:02--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/474_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 474427387 (452M) [application/zip]
# Saving to: ‘474_P.zip’
#
# 474_P.zip           100%[===================>] 452.45M  8.85MB/s    in 44s
#
# 2023-01-24 04:13:47 (10.2 MB/s) - ‘474_P.zip’ saved [474427387/474427387]
#
# --2023-01-24 04:13:47--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/475_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 302175596 (288M) [application/zip]
# Saving to: ‘475_P.zip’
#
# 475_P.zip           100%[===================>] 288.18M  14.9MB/s    in 23s
#
# 2023-01-24 04:14:10 (12.6 MB/s) - ‘475_P.zip’ saved [302175596/302175596]
#
# --2023-01-24 04:14:10--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/476_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 307834987 (294M) [application/zip]
# Saving to: ‘476_P.zip’
#
# 476_P.zip           100%[===================>] 293.57M  18.0MB/s    in 19s
#
# 2023-01-24 04:14:29 (15.5 MB/s) - ‘476_P.zip’ saved [307834987/307834987]
#
# --2023-01-24 04:14:29--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/477_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 634851417 (605M) [application/zip]
# Saving to: ‘477_P.zip’
#
# 477_P.zip           100%[===================>] 605.44M  11.8MB/s    in 48s
#
# 2023-01-24 04:15:18 (12.6 MB/s) - ‘477_P.zip’ saved [634851417/634851417]
#
# --2023-01-24 04:15:18--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/478_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 477215889 (455M) [application/zip]
# Saving to: ‘478_P.zip’
#
# 478_P.zip           100%[===================>] 455.11M  19.3MB/s    in 21s
#
# 2023-01-24 04:15:39 (21.5 MB/s) - ‘478_P.zip’ saved [477215889/477215889]
#
# --2023-01-24 04:15:40--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/479_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 467816257 (446M) [application/zip]
# Saving to: ‘479_P.zip’
#
# 479_P.zip           100%[===================>] 446.14M  13.4MB/s    in 31s
#
# 2023-01-24 04:16:11 (14.5 MB/s) - ‘479_P.zip’ saved [467816257/467816257]
#
# --2023-01-24 04:16:11--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/480_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 440476993 (420M) [application/zip]
# Saving to: ‘480_P.zip’
#
# 480_P.zip           100%[===================>] 420.07M  12.5MB/s    in 35s
#
# 2023-01-24 04:16:46 (11.9 MB/s) - ‘480_P.zip’ saved [440476993/440476993]
#
# --2023-01-24 04:16:47--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/481_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 578459636 (552M) [application/zip]
# Saving to: ‘481_P.zip’
#
# 481_P.zip           100%[===================>] 551.66M  11.8MB/s    in 34s
#
# 2023-01-24 04:17:21 (16.3 MB/s) - ‘481_P.zip’ saved [578459636/578459636]
#
# --2023-01-24 04:17:21--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/482_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 528925044 (504M) [application/zip]
# Saving to: ‘482_P.zip’
#
# 482_P.zip           100%[===================>] 504.42M  16.9MB/s    in 27s
#
# 2023-01-24 04:17:48 (18.5 MB/s) - ‘482_P.zip’ saved [528925044/528925044]
#
# --2023-01-24 04:17:48--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/483_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 778116028 (742M) [application/zip]
# Saving to: ‘483_P.zip’
#
# 483_P.zip           100%[===================>] 742.07M  15.0MB/s    in 52s
#
# 2023-01-24 04:18:41 (14.2 MB/s) - ‘483_P.zip’ saved [778116028/778116028]
#
# --2023-01-24 04:18:41--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/484_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 506084096 (483M) [application/zip]
# Saving to: ‘484_P.zip’
#
# 484_P.zip           100%[===================>] 482.64M  9.20MB/s    in 39s
#
# 2023-01-24 04:19:21 (12.3 MB/s) - ‘484_P.zip’ saved [506084096/506084096]
#
# --2023-01-24 04:19:21--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/485_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 296338923 (283M) [application/zip]
# Saving to: ‘485_P.zip’
#
# 485_P.zip           100%[===================>] 282.61M  10.5MB/s    in 24s
#
# 2023-01-24 04:19:45 (11.8 MB/s) - ‘485_P.zip’ saved [296338923/296338923]
#
# --2023-01-24 04:19:45--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/486_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 344331441 (328M) [application/zip]
# Saving to: ‘486_P.zip’
#
# 486_P.zip           100%[===================>] 328.38M  11.5MB/s    in 27s
#
# 2023-01-24 04:20:13 (12.0 MB/s) - ‘486_P.zip’ saved [344331441/344331441]
#
# --2023-01-24 04:20:13--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/487_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 528892266 (504M) [application/zip]
# Saving to: ‘487_P.zip’
#
# 487_P.zip           100%[===================>] 504.39M  6.64MB/s    in 44s
#
# 2023-01-24 04:20:57 (11.4 MB/s) - ‘487_P.zip’ saved [528892266/528892266]
#
# --2023-01-24 04:20:57--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/488_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 404726082 (386M) [application/zip]
# Saving to: ‘488_P.zip’
#
# 488_P.zip           100%[===================>] 385.98M  9.76MB/s    in 43s
#
# 2023-01-24 04:21:41 (8.94 MB/s) - ‘488_P.zip’ saved [404726082/404726082]
#
# --2023-01-24 04:21:41--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/489_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 365493220 (349M) [application/zip]
# Saving to: ‘489_P.zip’
#
# 489_P.zip           100%[===================>] 348.56M  6.08MB/s    in 28s
#
# 2023-01-24 04:22:09 (12.6 MB/s) - ‘489_P.zip’ saved [365493220/365493220]
#
# --2023-01-24 04:22:09--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/490_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 350149236 (334M) [application/zip]
# Saving to: ‘490_P.zip’
#
# 490_P.zip           100%[===================>] 333.93M  12.9MB/s    in 26s
#
# 2023-01-24 04:22:36 (12.7 MB/s) - ‘490_P.zip’ saved [350149236/350149236]
#
# --2023-01-24 04:22:36--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/491_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 436247614 (416M) [application/zip]
# Saving to: ‘491_P.zip’
#
# 491_P.zip           100%[===================>] 416.04M  14.8MB/s    in 28s
#
# 2023-01-24 04:23:04 (14.8 MB/s) - ‘491_P.zip’ saved [436247614/436247614]
#
# --2023-01-24 04:23:04--  https://dcapswoz.ict.usc.edu/wwwdaicwoz/492_P.zip
# Resolving dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)... 68.181.7.39
# Connecting to dcapswoz.ict.usc.edu (dcapswoz.ict.usc.edu)|68.181.7.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 472780075 (451M) [application/zip]
# Saving to: ‘492_P.zip’
#
# 492_P.zip           100%[===================>] 450.88M  12.9MB/s    in 51s
#
# 2023-01-24 04:23:56 (8.86 MB/s) - ‘492_P.zip’ saved [472780075/472780075]

# %% [markdown]
# **Importing Google Drive to Work with Colab**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Move All Zip Files from Colab to Drive for permanent storage**

# %%
import os
os.chdir('/content/drive/MyDrive/DAIC')

# %%
# !mv *.zip "/content/drive/MyDrive/DAIC"
# Out:
# mv: '300_P.zip' and '/content/drive/MyDrive/DAIC/300_P.zip' are the same file
# mv: '301_P.zip' and '/content/drive/MyDrive/DAIC/301_P.zip' are the same file
# mv: '302_P.zip' and '/content/drive/MyDrive/DAIC/302_P.zip' are the same file
# mv: '303_P.zip' and '/content/drive/MyDrive/DAIC/303_P.zip' are the same file
# mv: '304_P.zip' and '/content/drive/MyDrive/DAIC/304_P.zip' are the same file
# mv: '305_P.zip' and '/content/drive/MyDrive/DAIC/305_P.zip' are the same file
# mv: '306_P.zip' and '/content/drive/MyDrive/DAIC/306_P.zip' are the same file
# mv: '307_P.zip' and '/content/drive/MyDrive/DAIC/307_P.zip' are the same file
# mv: '308_P.zip' and '/content/drive/MyDrive/DAIC/308_P.zip' are the same file
# mv: '309_P.zip' and '/content/drive/MyDrive/DAIC/309_P.zip' are the same file
# mv: '310_P.zip' and '/content/drive/MyDrive/DAIC/310_P.zip' are the same file
# mv: '311_P.zip' and '/content/drive/MyDrive/DAIC/311_P.zip' are the same file
# mv: '312_P.zip' and '/content/drive/MyDrive/DAIC/312_P.zip' are the same file
# mv: '313_P.zip' and '/content/drive/MyDrive/DAIC/313_P.zip' are the same file
# mv: '314_P.zip' and '/content/drive/MyDrive/DAIC/314_P.zip' are the same file
# mv: '315_P.zip' and '/content/drive/MyDrive/DAIC/315_P.zip' are the same file
# mv: '316_P.zip' and '/content/drive/MyDrive/DAIC/316_P.zip' are the same file
# mv: '317_P.zip' and '/content/drive/MyDrive/DAIC/317_P.zip' are the same file
# mv: '318_P.zip' and '/content/drive/MyDrive/DAIC/318_P.zip' are the same file
# mv: '319_P.zip' and '/content/drive/MyDrive/DAIC/319_P.zip' are the same file
# mv: '320_P.zip' and '/content/drive/MyDrive/DAIC/320_P.zip' are the same file
# mv: '321_P.zip' and '/content/drive/MyDrive/DAIC/321_P.zip' are the same file
# mv: '322_P.zip' and '/content/drive/MyDrive/DAIC/322_P.zip' are the same file
# mv: '323_P.zip' and '/content/drive/MyDrive/DAIC/323_P.zip' are the same file
# mv: '324_P.zip' and '/content/drive/MyDrive/DAIC/324_P.zip' are the same file
# mv: '325_P.zip' and '/content/drive/MyDrive/DAIC/325_P.zip' are the same file
# mv: '326_P.zip' and '/content/drive/MyDrive/DAIC/326_P.zip' are the same file
# mv: '327_P.zip' and '/content/drive/MyDrive/DAIC/327_P.zip' are the same file
# mv: '328_P.zip' and '/content/drive/MyDrive/DAIC/328_P.zip' are the same file
# mv: '329_P.zip' and '/content/drive/MyDrive/DAIC/329_P.zip' are the same file
# mv: '330_P.zip' and '/content/drive/MyDrive/DAIC/330_P.zip' are the same file
# mv: '331_P.zip' and '/content/drive/MyDrive/DAIC/331_P.zip' are the same file
# mv: '332_P.zip' and '/content/drive/MyDrive/DAIC/332_P.zip' are the same file
# mv: '333_P.zip' and '/content/drive/MyDrive/DAIC/333_P.zip' are the same file
# mv: '334_P.zip' and '/content/drive/MyDrive/DAIC/334_P.zip' are the same file
# mv: '335_P.zip' and '/content/drive/MyDrive/DAIC/335_P.zip' are the same file
# mv: '336_P.zip' and '/content/drive/MyDrive/DAIC/336_P.zip' are the same file
# mv: '337_P.zip' and '/content/drive/MyDrive/DAIC/337_P.zip' are the same file
# mv: '338_P.zip' and '/content/drive/MyDrive/DAIC/338_P.zip' are the same file
# mv: '339_P.zip' and '/content/drive/MyDrive/DAIC/339_P.zip' are the same file
# mv: '340_P.zip' and '/content/drive/MyDrive/DAIC/340_P.zip' are the same file
# mv: '341_P.zip' and '/content/drive/MyDrive/DAIC/341_P.zip' are the same file
# mv: '343_P.zip' and '/content/drive/MyDrive/DAIC/343_P.zip' are the same file
# mv: '344_P.zip' and '/content/drive/MyDrive/DAIC/344_P.zip' are the same file
# mv: '345_P.zip' and '/content/drive/MyDrive/DAIC/345_P.zip' are the same file
# mv: '346_P.zip' and '/content/drive/MyDrive/DAIC/346_P.zip' are the same file
# mv: '347_P.zip' and '/content/drive/MyDrive/DAIC/347_P.zip' are the same file
# mv: '348_P.zip' and '/content/drive/MyDrive/DAIC/348_P.zip' are the same file
# mv: '349_P.zip' and '/content/drive/MyDrive/DAIC/349_P.zip' are the same file
# mv: '350_P.zip' and '/content/drive/MyDrive/DAIC/350_P.zip' are the same file
# mv: '351_P.zip' and '/content/drive/MyDrive/DAIC/351_P.zip' are the same file
# mv: '352_P.zip' and '/content/drive/MyDrive/DAIC/352_P.zip' are the same file
# mv: '353_P.zip' and '/content/drive/MyDrive/DAIC/353_P.zip' are the same file
# mv: '354_P.zip' and '/content/drive/MyDrive/DAIC/354_P.zip' are the same file
# mv: '355_P.zip' and '/content/drive/MyDrive/DAIC/355_P.zip' are the same file
# mv: '356_P.zip' and '/content/drive/MyDrive/DAIC/356_P.zip' are the same file
# mv: '357_P.zip' and '/content/drive/MyDrive/DAIC/357_P.zip' are the same file
# mv: '358_P.zip' and '/content/drive/MyDrive/DAIC/358_P.zip' are the same file
# mv: '359_P.zip' and '/content/drive/MyDrive/DAIC/359_P.zip' are the same file
# mv: '360_P.zip' and '/content/drive/MyDrive/DAIC/360_P.zip' are the same file
# mv: '361_P.zip' and '/content/drive/MyDrive/DAIC/361_P.zip' are the same file
# mv: '362_P.zip' and '/content/drive/MyDrive/DAIC/362_P.zip' are the same file
# mv: '363_P.zip' and '/content/drive/MyDrive/DAIC/363_P.zip' are the same file
# mv: '364_P.zip' and '/content/drive/MyDrive/DAIC/364_P.zip' are the same file
# mv: '365_P.zip' and '/content/drive/MyDrive/DAIC/365_P.zip' are the same file
# mv: '366_P.zip' and '/content/drive/MyDrive/DAIC/366_P.zip' are the same file
# mv: '367_P.zip' and '/content/drive/MyDrive/DAIC/367_P.zip' are the same file
# mv: '368_P.zip' and '/content/drive/MyDrive/DAIC/368_P.zip' are the same file
# mv: '369_P.zip' and '/content/drive/MyDrive/DAIC/369_P.zip' are the same file
# mv: '370_P.zip' and '/content/drive/MyDrive/DAIC/370_P.zip' are the same file
# mv: '371_P.zip' and '/content/drive/MyDrive/DAIC/371_P.zip' are the same file
# mv: '372_P.zip' and '/content/drive/MyDrive/DAIC/372_P.zip' are the same file
# mv: '373_P.zip' and '/content/drive/MyDrive/DAIC/373_P.zip' are the same file
# mv: '374_P.zip' and '/content/drive/MyDrive/DAIC/374_P.zip' are the same file
# mv: '375_P.zip' and '/content/drive/MyDrive/DAIC/375_P.zip' are the same file
# mv: '376_P.zip' and '/content/drive/MyDrive/DAIC/376_P.zip' are the same file
# mv: '377_P.zip' and '/content/drive/MyDrive/DAIC/377_P.zip' are the same file
# mv: '378_P.zip' and '/content/drive/MyDrive/DAIC/378_P.zip' are the same file
# mv: '379_P.zip' and '/content/drive/MyDrive/DAIC/379_P.zip' are the same file
# mv: '380_P.zip' and '/content/drive/MyDrive/DAIC/380_P.zip' are the same file
# mv: '381_P.zip' and '/content/drive/MyDrive/DAIC/381_P.zip' are the same file
# mv: '382_P.zip' and '/content/drive/MyDrive/DAIC/382_P.zip' are the same file
# mv: '383_P.zip' and '/content/drive/MyDrive/DAIC/383_P.zip' are the same file
# mv: '384_P.zip' and '/content/drive/MyDrive/DAIC/384_P.zip' are the same file
# mv: '385_P.zip' and '/content/drive/MyDrive/DAIC/385_P.zip' are the same file
# mv: '386_P.zip' and '/content/drive/MyDrive/DAIC/386_P.zip' are the same file
# mv: '387_P.zip' and '/content/drive/MyDrive/DAIC/387_P.zip' are the same file
# mv: '388_P.zip' and '/content/drive/MyDrive/DAIC/388_P.zip' are the same file
# mv: '389_P.zip' and '/content/drive/MyDrive/DAIC/389_P.zip' are the same file
# mv: '390_P.zip' and '/content/drive/MyDrive/DAIC/390_P.zip' are the same file
# mv: '391_P.zip' and '/content/drive/MyDrive/DAIC/391_P.zip' are the same file
# mv: '392_P.zip' and '/content/drive/MyDrive/DAIC/392_P.zip' are the same file
# mv: '393_P.zip' and '/content/drive/MyDrive/DAIC/393_P.zip' are the same file
# mv: '395_P.zip' and '/content/drive/MyDrive/DAIC/395_P.zip' are the same file
# mv: '396_P.zip' and '/content/drive/MyDrive/DAIC/396_P.zip' are the same file
# mv: '397_P.zip' and '/content/drive/MyDrive/DAIC/397_P.zip' are the same file
# mv: '399_P.zip' and '/content/drive/MyDrive/DAIC/399_P.zip' are the same file
# mv: '400_P.zip' and '/content/drive/MyDrive/DAIC/400_P.zip' are the same file
# mv: '401_P.zip' and '/content/drive/MyDrive/DAIC/401_P.zip' are the same file
# mv: '402_P.zip' and '/content/drive/MyDrive/DAIC/402_P.zip' are the same file
# mv: '403_P.zip' and '/content/drive/MyDrive/DAIC/403_P.zip' are the same file
# mv: '404_P.zip' and '/content/drive/MyDrive/DAIC/404_P.zip' are the same file
# mv: '405_P.zip' and '/content/drive/MyDrive/DAIC/405_P.zip' are the same file
# mv: '406_P.zip' and '/content/drive/MyDrive/DAIC/406_P.zip' are the same file
# mv: '407_P.zip' and '/content/drive/MyDrive/DAIC/407_P.zip' are the same file
# mv: '408_P.zip' and '/content/drive/MyDrive/DAIC/408_P.zip' are the same file
# mv: '409_P.zip' and '/content/drive/MyDrive/DAIC/409_P.zip' are the same file
# mv: '410_P.zip' and '/content/drive/MyDrive/DAIC/410_P.zip' are the same file
# mv: '411_P.zip' and '/content/drive/MyDrive/DAIC/411_P.zip' are the same file
# mv: '412_P.zip' and '/content/drive/MyDrive/DAIC/412_P.zip' are the same file
# mv: '413_P.zip' and '/content/drive/MyDrive/DAIC/413_P.zip' are the same file
# mv: '414_P.zip' and '/content/drive/MyDrive/DAIC/414_P.zip' are the same file
# mv: '415_P.zip' and '/content/drive/MyDrive/DAIC/415_P.zip' are the same file
# mv: '416_P.zip' and '/content/drive/MyDrive/DAIC/416_P.zip' are the same file
# mv: '417_P.zip' and '/content/drive/MyDrive/DAIC/417_P.zip' are the same file
# mv: '418_P.zip' and '/content/drive/MyDrive/DAIC/418_P.zip' are the same file
# mv: '419_P.zip' and '/content/drive/MyDrive/DAIC/419_P.zip' are the same file
# mv: '420_P.zip' and '/content/drive/MyDrive/DAIC/420_P.zip' are the same file
# mv: '421_P.zip' and '/content/drive/MyDrive/DAIC/421_P.zip' are the same file
# mv: '422_P.zip' and '/content/drive/MyDrive/DAIC/422_P.zip' are the same file
# mv: '423_P.zip' and '/content/drive/MyDrive/DAIC/423_P.zip' are the same file
# mv: '424_P.zip' and '/content/drive/MyDrive/DAIC/424_P.zip' are the same file
# mv: '425_P.zip' and '/content/drive/MyDrive/DAIC/425_P.zip' are the same file
# mv: '426_P.zip' and '/content/drive/MyDrive/DAIC/426_P.zip' are the same file
# mv: '427_P.zip' and '/content/drive/MyDrive/DAIC/427_P.zip' are the same file
# mv: '428_P.zip' and '/content/drive/MyDrive/DAIC/428_P.zip' are the same file
# mv: '429_P.zip' and '/content/drive/MyDrive/DAIC/429_P.zip' are the same file
# mv: '430_P.zip' and '/content/drive/MyDrive/DAIC/430_P.zip' are the same file
# mv: '431_P.zip' and '/content/drive/MyDrive/DAIC/431_P.zip' are the same file
# mv: '432_P.zip' and '/content/drive/MyDrive/DAIC/432_P.zip' are the same file
# mv: '433_P.zip' and '/content/drive/MyDrive/DAIC/433_P.zip' are the same file
# mv: '434_P.zip' and '/content/drive/MyDrive/DAIC/434_P.zip' are the same file
# mv: '435_P.zip' and '/content/drive/MyDrive/DAIC/435_P.zip' are the same file
# mv: '436_P.zip' and '/content/drive/MyDrive/DAIC/436_P.zip' are the same file
# mv: '437_P.zip' and '/content/drive/MyDrive/DAIC/437_P.zip' are the same file
# mv: '438_P.zip' and '/content/drive/MyDrive/DAIC/438_P.zip' are the same file
# mv: '439_P.zip' and '/content/drive/MyDrive/DAIC/439_P.zip' are the same file
# mv: '440_P.zip' and '/content/drive/MyDrive/DAIC/440_P.zip' are the same file
# mv: '441_P.zip' and '/content/drive/MyDrive/DAIC/441_P.zip' are the same file
# mv: '442_P.zip' and '/content/drive/MyDrive/DAIC/442_P.zip' are the same file
# mv: '443_P.zip' and '/content/drive/MyDrive/DAIC/443_P.zip' are the same file
# mv: '444_P.zip' and '/content/drive/MyDrive/DAIC/444_P.zip' are the same file
# mv: '445_P.zip' and '/content/drive/MyDrive/DAIC/445_P.zip' are the same file
# mv: '446_P.zip' and '/content/drive/MyDrive/DAIC/446_P.zip' are the same file
# mv: '447_P.zip' and '/content/drive/MyDrive/DAIC/447_P.zip' are the same file
# mv: '448_P.zip' and '/content/drive/MyDrive/DAIC/448_P.zip' are the same file
# mv: '449_P.zip' and '/content/drive/MyDrive/DAIC/449_P.zip' are the same file
# mv: '450_P.zip' and '/content/drive/MyDrive/DAIC/450_P.zip' are the same file
# mv: '451_P.zip' and '/content/drive/MyDrive/DAIC/451_P.zip' are the same file
# mv: '452_P.zip' and '/content/drive/MyDrive/DAIC/452_P.zip' are the same file
# mv: '453_P.zip' and '/content/drive/MyDrive/DAIC/453_P.zip' are the same file
# mv: '454_P.zip' and '/content/drive/MyDrive/DAIC/454_P.zip' are the same file
# mv: '455_P.zip' and '/content/drive/MyDrive/DAIC/455_P.zip' are the same file
# mv: '456_P.zip' and '/content/drive/MyDrive/DAIC/456_P.zip' are the same file
# mv: '457_P.zip' and '/content/drive/MyDrive/DAIC/457_P.zip' are the same file
# mv: '458_P.zip' and '/content/drive/MyDrive/DAIC/458_P.zip' are the same file
# mv: '459_P.zip' and '/content/drive/MyDrive/DAIC/459_P.zip' are the same file
# mv: '461_P.zip' and '/content/drive/MyDrive/DAIC/461_P.zip' are the same file
# mv: '462_P.zip' and '/content/drive/MyDrive/DAIC/462_P.zip' are the same file
# mv: '463_P.zip' and '/content/drive/MyDrive/DAIC/463_P.zip' are the same file
# mv: '464_P.zip' and '/content/drive/MyDrive/DAIC/464_P.zip' are the same file
# mv: '465_P.zip' and '/content/drive/MyDrive/DAIC/465_P.zip' are the same file
# mv: '466_P.zip' and '/content/drive/MyDrive/DAIC/466_P.zip' are the same file
# mv: '467_P.zip' and '/content/drive/MyDrive/DAIC/467_P.zip' are the same file
# mv: '468_P.zip' and '/content/drive/MyDrive/DAIC/468_P.zip' are the same file
# mv: '469_P.zip' and '/content/drive/MyDrive/DAIC/469_P.zip' are the same file
# mv: '470_P.zip' and '/content/drive/MyDrive/DAIC/470_P.zip' are the same file
# mv: '471_P.zip' and '/content/drive/MyDrive/DAIC/471_P.zip' are the same file
# mv: '472_P.zip' and '/content/drive/MyDrive/DAIC/472_P.zip' are the same file
# mv: '473_P.zip' and '/content/drive/MyDrive/DAIC/473_P.zip' are the same file
# mv: '474_P.zip' and '/content/drive/MyDrive/DAIC/474_P.zip' are the same file
# mv: '475_P.zip' and '/content/drive/MyDrive/DAIC/475_P.zip' are the same file
# mv: '476_P.zip' and '/content/drive/MyDrive/DAIC/476_P.zip' are the same file
# mv: '477_P.zip' and '/content/drive/MyDrive/DAIC/477_P.zip' are the same file
# mv: '478_P.zip' and '/content/drive/MyDrive/DAIC/478_P.zip' are the same file
# mv: '479_P.zip' and '/content/drive/MyDrive/DAIC/479_P.zip' are the same file
# mv: '480_P.zip' and '/content/drive/MyDrive/DAIC/480_P.zip' are the same file
# mv: '481_P.zip' and '/content/drive/MyDrive/DAIC/481_P.zip' are the same file
# mv: '482_P.zip' and '/content/drive/MyDrive/DAIC/482_P.zip' are the same file
# mv: '483_P.zip' and '/content/drive/MyDrive/DAIC/483_P.zip' are the same file
# mv: '484_P.zip' and '/content/drive/MyDrive/DAIC/484_P.zip' are the same file
# mv: '485_P.zip' and '/content/drive/MyDrive/DAIC/485_P.zip' are the same file
# mv: '486_P.zip' and '/content/drive/MyDrive/DAIC/486_P.zip' are the same file
# mv: '487_P.zip' and '/content/drive/MyDrive/DAIC/487_P.zip' are the same file
# mv: '488_P.zip' and '/content/drive/MyDrive/DAIC/488_P.zip' are the same file
# mv: '489_P.zip' and '/content/drive/MyDrive/DAIC/489_P.zip' are the same file
# mv: '490_P.zip' and '/content/drive/MyDrive/DAIC/490_P.zip' are the same file
# mv: '491_P.zip' and '/content/drive/MyDrive/DAIC/491_P.zip' are the same file
# mv: '492_P.zip' and '/content/drive/MyDrive/DAIC/492_P.zip' are the same file
# mv: 'documents.zip' and '/content/drive/MyDrive/DAIC/documents.zip' are the same file
# mv: 'util.zip' and '/content/drive/MyDrive/DAIC/util.zip' are the same file

# %%
# !cd "/content/drive/MyDrive/DAIC"

# %% [markdown]
# **Making directories and unzipping to respective locations **

# %%
# !mkdir train_data
# !mkdir test_data
# !mkdir dev_data
# Out:
# mkdir: cannot create directory ‘train_data’: File exists
# mkdir: cannot create directory ‘test_data’: File exists
# mkdir: cannot create directory ‘dev_data’: File exists

# %%
import numpy as np
import pandas as pd

# %%
dev = np.array(pd.read_csv('/content/drive/MyDrive/DAIC/dev_split_Depression_AVEC2017.csv',delimiter=',',encoding='utf-8'))[:, 0:2]
test = np.array(pd.read_csv('/content/drive/MyDrive/DAIC/full_test_split.csv',delimiter=',',encoding='utf-8'))[:, 0:2]
train = np.array(pd.read_csv('/content/drive/MyDrive/DAIC/train_split_Depression_AVEC2017.csv',delimiter=',',encoding='utf-8'))[:, 0:2]

# %%
for i in range(len(dev)):
      s = str(int(dev[i][0])) + "_P.zip"
      # !unzip -q {s} -d dev_data
for i in range(len(test)):
      s = str(int(test[i][0])) + "_P.zip"
      # !unzip -q {s} -d test_data
for i in range(len(train)):
      s = str(int(train[i][0])) + "_P.zip"
      # !unzip -q {s} -d train_data
